# %%
# Pyfolio allows for the comprehensive analysis of stocks, portfolios, and trading strategies.
# Here is a simple example where we produce a set of plots, called a tear sheet, for a single stock.

# %%
# %matplotlib inline
import pyfolio as pf

# %%
stock_rets = pf.utils.get_symbol_rets('FB') # Fetch the daily returns for a stock

# %%
# Create a full tear sheet for the single stock.
# This will show statistics and plots about returns and shock events.
# Set the first 80% of the stock's history to be in-sample (controls the cone plot).
# The Bayesian tear sheet is also enabled.
pf.create_full_tear_sheet(stock_rets, backtest_days_pct=0.8, bayesian=True)
# Out:
# Entire data start date: 2012-05-21 00:00:00
# Entire data end date: 2015-07-09 00:00:00
#
#
# Out-of-Sample Months: 7
# Backtest Months: 30
#                    Backtest  Out_of_Sample  All_History
# sortino_ratio          1.53           2.34         1.52
# omega_ratio            1.16           1.23         1.16
# max_drawdown          -0.48          -0.09        -0.48
# calmar_ratio           0.78           2.95         0.74
# annual_return          0.38           0.27         0.36
# stability              0.84           0.54         0.87
# sharpe_ratio           0.77           1.23         0.80
# annual_volatility      0.49           0.22         0.45
# alpha                  0.17           0.25         0.19
# beta                   0.97           1.01         0.98
#
# Worst Drawdown Periods
#    net drawdown in %  peak date valley date recovery date duration
# 0              47.90 2012-05-21  2012-09-04    2013-07-25      309
# ...
